# %%
import xarray as xr

ds = xr.open_dataset(
    "../../storage/root/data/nsa.aml_lidar-lidar-10s.a1/nsa.aml_lidar-lidar-10s.a1.20211222.203010.nc"
)

# %%
ds
# Out:
# <xarray.Dataset>
# Dimensions:                     (time: 60)
# Coordinates:
#   * time                        (time) datetime64[ns] 2021-12-22T20:30:10 ......
# Data variables: (12/36)
#     precipitation_intensity     (time) float64 ...
#     total_precipitation         (time) float64 ...
#     weather_code_synop          (time) int64 ...
#     weather_code_metar          (time) object ...
#     weather_code_nws            (time) object ...
#     radar_reflectivity          (time) float64 ...
#     ...                          ...
#     qc_kinetic_energy           (time) int32 ...
#     qc_snow_intensity           (time) int32 ...
#     qc_sensor_temperature       (time) int32 ...
#     qc_longitude                int32 ...
#     qc_altitude                 int32 ...
#     qc_latitude                 int32 ...
# Attributes: (12/13)
#     title:         aml_lidar
#     description:   AWAKEN Laser Disdrometer ingest pipeline
#     conventions:   MHKiT-Cloud Data Standards v1.0
# ...
